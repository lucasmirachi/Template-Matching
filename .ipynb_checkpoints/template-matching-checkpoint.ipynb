# %% [markdown]
# # Template Matching using Python and OpenCV

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('mechanics-garage-kyle-simpson.jpg')

cv2.imshow('img',img)
cv2.waitKey(1) & 0xFF == ord('q')
cv2.destroyAllWindows
# Out:
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# QObject::moveToThread: Current thread (0x21a52f0) is not the object's thread (0x2d748f0).
# Cannot move to target thread (0x21a52f0)
#
# ...
